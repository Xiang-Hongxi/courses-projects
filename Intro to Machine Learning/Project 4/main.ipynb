# %%
from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import torch
import torchvision
import torchvision.transforms as transforms
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
RANDOM_SEED = 42
EPOCHS = 100
EPOCHS_TRAIN = 1000
BATCH_SIZE = 256
BATCH_SIZE_TRAIN = 20
PRETRAIN_PATH = './pretrainmodel8.pth'
TRAIN_PATH = './model8.pth'
SAVE_PATH ='./prediction8.csv'

np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
df_pretrain_features = pd.read_csv('./data/pretrain_features.csv')
df_pretrain_labels = pd.read_csv('./data/pretrain_labels.csv')

# %%
pretrain_features = df_pretrain_features.iloc[:,2:].to_numpy(dtype=np.dtype(np.float32))
pretrain_labels = df_pretrain_labels.iloc[:,1:].to_numpy(dtype=np.dtype(np.float32))
# print(np.shape(pretrain_features))
# pretrain_features

# %%
print(np.shape(pretrain_labels))
# Out:
# (50000, 1)

# %%
pretrian_data = np.hstack((pretrain_features, pretrain_labels))
print(pretrian_data[:, -1:].shape[0])
# Out:
# 50000

# %%
pre_train_set, pre_valid_set = train_test_split(pretrian_data, test_size=0.1, random_state=RANDOM_SEED)

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, data, training=False):
        self.training = training
        if self.training:
            self.features = data[:, :-1]
            self.labels = data[:, -1:]
        else:
            self.features = data[:]
        
    
    def __getitem__(self, index):
        feature_i = self.features[index] 
        if self.training:
            label_i = self.labels[index]
            return feature_i, label_i
        else:
            return feature_i
    def __len__(self):
        return self.features.shape[0]

pre_train_dataset = MyDataset(pre_train_set, training=True)
pre_valid_dataset = MyDataset(pre_valid_set, training=True)

# %%
from torch.utils.data import DataLoader

pre_train_loader = DataLoader(dataset=pre_train_dataset, batch_size=BATCH_SIZE)
pre_valid_loader = DataLoader(dataset=pre_valid_dataset, batch_size=BATCH_SIZE)

# %%
import torch.nn as nn
import torchvision.models as models

class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(1000, 512),
            nn.Tanh(),
            nn.Linear(512, 256),
            nn.Tanh(),
            nn.Linear(256,64),
            nn.Tanh(),
            nn.Linear(64, 32),
            nn.Tanh()
        )

        self.decoder = nn.Sequential(
            nn.Linear(32, 16),
            nn.Tanh(),
            nn.Linear(16, 1)
        )
    
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.encoder(x)
        x = self.decoder(x)
        return x

pretrain_model = AutoEncoder().to(device)

# %%
import torch.optim as optim

criterion = nn.MSELoss()
# optimizer = optim.SGD(pretrain_model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-5, nesterov=True)
optimizer = optim.Adam(pretrain_model.parameters(), lr=0.0001, weight_decay=1e-5)

# %%
def pretrain(model):
    min_loss = 100.0
    for epoch in range(EPOCHS):
        running_loss = 0.0
        valid_loss = 0.0

        print('Training')
        model.train()
        for i, data in enumerate(pre_train_loader):
            feature = data[0].to(device)
            label = data[1].to(device)
               
            optimizer.zero_grad()

            result = model(feature)
            loss = criterion(result, label)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        print(f'[{epoch + 1}] average loss per epoch: {running_loss / len(pre_train_loader):.8f}')

        print('Validation')
        model.eval()
        with torch.no_grad():
            for i, data in enumerate(pre_valid_loader):
                feature = data[0].to(device)
                label = data[1].to(device)
                result = model(feature)
                loss = criterion(result, label)
                valid_loss += loss.item()
        print(f'Average Validation loss per epoch: {valid_loss / len(pre_valid_loader):.8f}')
        
        if valid_loss <= min_loss:
            min_loss = valid_loss
            torch.save(model.state_dict(), PRETRAIN_PATH)

    print('Finished Training')

# %%
pretrain(pretrain_model)
# Out:
# Training
# [1] average loss per epoch: 4.10738450
# Validation
# Average Validation loss per epoch: 1.78243719
# Training
# [2] average loss per epoch: 1.18345387
# Validation
# Average Validation loss per epoch: 0.75413523
# Training
# [3] average loss per epoch: 0.54901719
# Validation
# Average Validation loss per epoch: 0.38696706
# Training
# [4] average loss per epoch: 0.30421613
# Validation
# Average Validation loss per epoch: 0.23807619
# Training
# [5] average loss per epoch: 0.20502085
# Validation
# Average Validation loss per epoch: 0.18007276
# Training
# [6] average loss per epoch: 0.16756095
# Validation
# Average Validation loss per epoch: 0.16001157
# Training
# [7] average loss per epoch: 0.15508236
# Validation
# Average Validation loss per epoch: 0.15416200
# Training
# [8] average loss per epoch: 0.15152386
# Validation
# Average Validation loss per epoch: 0.15280847
# Training
# [9] average loss per epoch: 0.15066928
# Validation
# Average Validation loss per epoch: 0.15259444
# Training
# [10] average loss per epoch: 0.15049591
# Validation
# Average Validation loss per epoch: 0.15258856
# Training
# [11] average loss per epoch: 0.15046342
# Validation
# Average Validation loss per epoch: 0.15259741
# Training
# [12] average loss per epoch: 0.15045453
# Validation
# Average Validation loss per epoch: 0.15259798
# Training
# [13] average loss per epoch: 0.15044827
# Validation
# Average Validation loss per epoch: 0.15259276
# Training
# [14] average loss per epoch: 0.15044108
# Validation
# Average Validation loss per epoch: 0.15258406
# Training
# [15] average loss per epoch: 0.15043180
# Validation
# Average Validation loss per epoch: 0.15257205
# Training
# [16] average loss per epoch: 0.15041918
# Validation
# Average Validation loss per epoch: 0.15255548
# Training
# [17] average loss per epoch: 0.15040105
# Validation
# Average Validation loss per epoch: 0.15253127
# Training
# [18] average loss per epoch: 0.15037284
# Validation
# Average Validation loss per epoch: 0.15249225
# Training
# [19] average loss per epoch: 0.15032278
# Validation
# Average Validation loss per epoch: 0.15241761
# Training
# [20] average loss per epoch: 0.15020709
# Validation
# Average Validation loss per epoch: 0.15221264
# Training
# [21] average loss per epoch: 0.14955486
# Validation
# Average Validation loss per epoch: 0.14954128
# Training
# [22] average loss per epoch: 0.08262885
# Validation
# Average Validation loss per epoch: 0.03651810
# Training
# [23] average loss per epoch: 0.02612074
# Validation
# Average Validation loss per epoch: 0.01944933
# Training
# [24] average loss per epoch: 0.01631780
# Validation
# Average Validation loss per epoch: 0.01420243
# Training
# [25] average loss per epoch: 0.01260425
# Validation
# Average Validation loss per epoch: 0.01178693
# Training
# [26] average loss per epoch: 0.01064974
# Validation
# Average Validation loss per epoch: 0.01040076
# Training
# [27] average loss per epoch: 0.00943738
# Validation
# Average Validation loss per epoch: 0.00951658
# Training
# [28] average loss per epoch: 0.00863234
# Validation
# Average Validation loss per epoch: 0.00890288
# Training
# [29] average loss per epoch: 0.00807762
# Validation
# Average Validation loss per epoch: 0.00846296
# Training
# [30] average loss per epoch: 0.00768340
# Validation
# Average Validation loss per epoch: 0.00814233
# Training
# [31] average loss per epoch: 0.00739226
# Validation
# Average Validation loss per epoch: 0.00790085
# Training
# [32] average loss per epoch: 0.00716707
# Validation
# Average Validation loss per epoch: 0.00771092
# Training
# [33] average loss per epoch: 0.00698433
# Validation
# Average Validation loss per epoch: 0.00755487
# Training
# [34] average loss per epoch: 0.00682952
# Validation
# Average Validation loss per epoch: 0.00742121
# Training
# [35] average loss per epoch: 0.00669376
# Validation
# Average Validation loss per epoch: 0.00730211
# Training
# [36] average loss per epoch: 0.00657144
# Validation
# Average Validation loss per epoch: 0.00719238
# Training
# [37] average loss per epoch: 0.00645879
# Validation
# Average Validation loss per epoch: 0.00708862
# Training
# [38] average loss per epoch: 0.00635323
# Validation
# Average Validation loss per epoch: 0.00698865
# Training
# [39] average loss per epoch: 0.00625294
# Validation
# Average Validation loss per epoch: 0.00689137
# Training
# [40] average loss per epoch: 0.00615659
# Validation
# Average Validation loss per epoch: 0.00679646
# Training
# [41] average loss per epoch: 0.00606299
# Validation
# Average Validation loss per epoch: 0.00670409
# Training
# [42] average loss per epoch: 0.00597087
# Validation
# Average Validation loss per epoch: 0.00661425
# Training
# [43] average loss per epoch: 0.00587888
# Validation
# Average Validation loss per epoch: 0.00652613
# Training
# [44] average loss per epoch: 0.00578573
# Validation
# Average Validation loss per epoch: 0.00643788
# Training
# [45] average loss per epoch: 0.00569036
# Validation
# Average Validation loss per epoch: 0.00634696
# Training
# [46] average loss per epoch: 0.00559222
# Validation
# Average Validation loss per epoch: 0.00625107
# Training
# [47] average loss per epoch: 0.00549135
# Validation
# Average Validation loss per epoch: 0.00614921
# Training
# [48] average loss per epoch: 0.00538844
# Validation
# Average Validation loss per epoch: 0.00604216
# Training
# [49] average loss per epoch: 0.00528458
# Validation
# Average Validation loss per epoch: 0.00593222
# Training
# [50] average loss per epoch: 0.00518087
# Validation
# Average Validation loss per epoch: 0.00582219
# Training
# [51] average loss per epoch: 0.00507800
# Validation
# Average Validation loss per epoch: 0.00571450
# Training
# [52] average loss per epoch: 0.00497608
# Validation
# Average Validation loss per epoch: 0.00561106
# Training
# [53] average loss per epoch: 0.00487485
# Validation
# Average Validation loss per epoch: 0.00551372
# Training
# [54] average loss per epoch: 0.00477418
# Validation
# Average Validation loss per epoch: 0.00542461
# Training
# [55] average loss per epoch: 0.00467461
# Validation
# Average Validation loss per epoch: 0.00534557
# Training
# [56] average loss per epoch: 0.00457752
# Validation
# Average Validation loss per epoch: 0.00527689
# Training
# [57] average loss per epoch: 0.00448438
# Validation
# Average Validation loss per epoch: 0.00521696
# Training
# [58] average loss per epoch: 0.00439595
# Validation
# Average Validation loss per epoch: 0.00516349
# Training
# [59] average loss per epoch: 0.00431217
# Validation
# Average Validation loss per epoch: 0.00511459
# Training
# [60] average loss per epoch: 0.00423266
# Validation
# Average Validation loss per epoch: 0.00506870
# Training
# [61] average loss per epoch: 0.00415696
# Validation
# Average Validation loss per epoch: 0.00502429
# Training
# [62] average loss per epoch: 0.00408455
# Validation
# Average Validation loss per epoch: 0.00497990
# Training
# [63] average loss per epoch: 0.00401493
# Validation
# Average Validation loss per epoch: 0.00493446
# Training
# [64] average loss per epoch: 0.00394763
# Validation
# Average Validation loss per epoch: 0.00488736
# Training
# [65] average loss per epoch: 0.00388221
# Validation
# Average Validation loss per epoch: 0.00483839
# Training
# [66] average loss per epoch: 0.00381834
# Validation
# Average Validation loss per epoch: 0.00478762
# Training
# [67] average loss per epoch: 0.00375574
# Validation
# Average Validation loss per epoch: 0.00473524
# Training
# [68] average loss per epoch: 0.00369422
# Validation
# Average Validation loss per epoch: 0.00468149
# Training
# [69] average loss per epoch: 0.00363363
# Validation
# Average Validation loss per epoch: 0.00462659
# Training
# [70] average loss per epoch: 0.00357391
# Validation
# Average Validation loss per epoch: 0.00457076
# Training
# [71] average loss per epoch: 0.00351508
# Validation
# Average Validation loss per epoch: 0.00451407
# Training
# [72] average loss per epoch: 0.00345727
# Validation
# Average Validation loss per epoch: 0.00445644
# Training
# [73] average loss per epoch: 0.00340067
# Validation
# Average Validation loss per epoch: 0.00439761
# Training
# [74] average loss per epoch: 0.00334553
# Validation
# Average Validation loss per epoch: 0.00433725
# Training
# [75] average loss per epoch: 0.00329208
# Validation
# Average Validation loss per epoch: 0.00427531
# Training
# [76] average loss per epoch: 0.00324050
# Validation
# Average Validation loss per epoch: 0.00421260
# Training
# [77] average loss per epoch: 0.00319095
# Validation
# Average Validation loss per epoch: 0.00415110
# Training
# [78] average loss per epoch: 0.00314377
# Validation
# Average Validation loss per epoch: 0.00409339
# Training
# [79] average loss per epoch: 0.00309981
# Validation
# Average Validation loss per epoch: 0.00404119
# Training
# [80] average loss per epoch: 0.00306086
# Validation
# Average Validation loss per epoch: 0.00399482
# Training
# [81] average loss per epoch: 0.00302912
# Validation
# Average Validation loss per epoch: 0.00395428
# Training
# [82] average loss per epoch: 0.00300063
# Validation
# Average Validation loss per epoch: 0.00392075
# Training
# [83] average loss per epoch: 0.00295812
# Validation
# Average Validation loss per epoch: 0.00390272
# Training
# [84] average loss per epoch: 0.00290159
# Validation
# Average Validation loss per epoch: 0.00387522
# Training
# [85] average loss per epoch: 0.00284515
# Validation
# Average Validation loss per epoch: 0.00382982
# Training
# [86] average loss per epoch: 0.00279211
# Validation
# Average Validation loss per epoch: 0.00378239
# Training
# [87] average loss per epoch: 0.00274216
# Validation
# Average Validation loss per epoch: 0.00373807
# Training
# [88] average loss per epoch: 0.00269466
# Validation
# Average Validation loss per epoch: 0.00369622
# Training
# [89] average loss per epoch: 0.00264917
# Validation
# Average Validation loss per epoch: 0.00365647
# Training
# [90] average loss per epoch: 0.00260541
# Validation
# Average Validation loss per epoch: 0.00361929
# Training
# [91] average loss per epoch: 0.00256304
# Validation
# Average Validation loss per epoch: 0.00358496
# Training
# [92] average loss per epoch: 0.00252175
# Validation
# Average Validation loss per epoch: 0.00355426
# Training
# [93] average loss per epoch: 0.00248176
# Validation
# Average Validation loss per epoch: 0.00352916
# Training
# [94] average loss per epoch: 0.00244353
# Validation
# Average Validation loss per epoch: 0.00351027
# Training
# [95] average loss per epoch: 0.00240677
# Validation
# Average Validation loss per epoch: 0.00349220
# Training
# [96] average loss per epoch: 0.00237092
# Validation
# Average Validation loss per epoch: 0.00346655
# Training
# [97] average loss per epoch: 0.00233607
# Validation
# Average Validation loss per epoch: 0.00343308
# Training
# [98] average loss per epoch: 0.00230304
# Validation
# Average Validation loss per epoch: 0.00340099
# Training
# [99] average loss per epoch: 0.00227221
# Validation
# Average Validation loss per epoch: 0.00337558
# Training
# [100] average loss per epoch: 0.00224327
# Validation
# Average Validation loss per epoch: 0.00335359
# Finished Training

# %%
df_train_features = pd.read_csv('./data/train_features.csv')
df_train_labels = pd.read_csv('./data/train_labels.csv')
df_test_features = pd.read_csv('./data/test_features.csv')

# %%
train_features = df_train_features.iloc[:,2:].to_numpy(dtype=np.dtype(np.float32))
train_labels = df_train_labels.iloc[:,1:].to_numpy(dtype=np.dtype(np.float32))
test_id = df_test_features.iloc[:,0:1].to_numpy(dtype='str')
test_features = df_test_features.iloc[:,2:].to_numpy(dtype=np.dtype(np.float32))
print(np.shape(test_features[:]))
print(np.shape(train_features[:]))
# Out:
# (10000, 1000)
# (100, 1000)

# %%
trian_data = np.hstack((train_features, train_labels))
print(trian_data[:, :-1].shape)
# Out:
# (100, 1000)

# %%
train_set, valid_set = train_test_split(trian_data, test_size=0.1, random_state=RANDOM_SEED)

# %%
train_dataset = MyDataset(train_set, training=True)
valid_dataset = MyDataset(valid_set, training=True)
test_dataset = MyDataset(test_features, training=False)

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE_TRAIN)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE_TRAIN)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE)

# %%
class myLayer(nn.Module):
    def __init__(self):
        super(myLayer, self).__init__()
        self.fc1 = nn.Linear(32, 16)
        self.fc2 = nn.Linear(16, 1)
        # self.drop = nn.Dropout(p=0.5)
        self.activation_fn = nn.Tanh()
        
    def forward(self, x):
        x = self.fc1(x)
        x = self.activation_fn(x)
        # x = self.drop(x)
        x = self.fc2(x)
        return x

pretrain_model.load_state_dict(torch.load(PRETRAIN_PATH))

for param in pretrain_model.parameters():
    param.requires_grad = False

pretrain_model.decoder = myLayer()

model = pretrain_model.to(device)

# %%
criterion2 = nn.MSELoss()
# optimizer2 = optim.SGD(pretrain_model.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-5, nesterov=True)
optimizer2 = optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-5)

# %%
def adjust_lr(optimizer, epoch):
    if epoch >= 500:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.005
    if epoch >= 800:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.001

# %%
def train(model):
    min_loss = 100
    for epoch in range(EPOCHS_TRAIN):
        running_loss = 0.0
        valid_loss = 0.0

        print('Training')
        model.train()
        for i, data in enumerate(train_loader):
            feature = data[0].to(device)
            label = data[1].to(device)
            
            # adjust_lr(optimizer2, epoch)
            optimizer2.zero_grad()

            result = model(feature)
            loss = criterion2(result, label)
            loss.backward()
            optimizer2.step()

            running_loss += loss.item()
        print(f'[{epoch + 1}] average loss per epoch: {running_loss / len(train_loader):.8f}')

        print('Validation')
        model.eval()
        with torch.no_grad():
            for i, data in enumerate(valid_loader):
                feature = data[0].to(device)
                label = data[1].to(device)
                result = model(feature)
                loss = criterion2(result, label)
                valid_loss += loss.item()
        print(f'Average Validation loss per epoch: {valid_loss / len(valid_loader):.8f}')
        
        if valid_loss <= min_loss:
            min_loss = valid_loss
            torch.save(model.state_dict(), TRAIN_PATH)

    print('Finished Training')

# %%
train(model)
# Out:
# Training
# [1] average loss per epoch: 1.00968401
# Validation
# Average Validation loss per epoch: 0.10504127
# Training
# [2] average loss per epoch: 0.23625587
# Validation
# Average Validation loss per epoch: 0.22053717
# Training
# [3] average loss per epoch: 0.21190385
# Validation
# Average Validation loss per epoch: 0.10263451
# Training
# [4] average loss per epoch: 0.11788520
# Validation
# Average Validation loss per epoch: 0.16368912
# Training
# [5] average loss per epoch: 0.16121083
# Validation
# Average Validation loss per epoch: 0.15336441
# Training
# [6] average loss per epoch: 0.13508664
# Validation
# Average Validation loss per epoch: 0.09889194
# Training
# [7] average loss per epoch: 0.12262123
# Validation
# Average Validation loss per epoch: 0.09876897
# Training
# [8] average loss per epoch: 0.11371921
# Validation
# Average Validation loss per epoch: 0.09488750
# Training
# [9] average loss per epoch: 0.10013146
# Validation
# Average Validation loss per epoch: 0.10562985
# Training
# [10] average loss per epoch: 0.10150630
# Validation
# Average Validation loss per epoch: 0.10049113
# Training
# [11] average loss per epoch: 0.09435907
# Validation
# Average Validation loss per epoch: 0.08977515
# Training
# [12] average loss per epoch: 0.08570777
# Validation
# Average Validation loss per epoch: 0.08730289
# Training
# [13] average loss per epoch: 0.07697457
# Validation
# Average Validation loss per epoch: 0.08875966
# Training
# [14] average loss per epoch: 0.07292135
# Validation
# Average Validation loss per epoch: 0.08970487
# Training
# [15] average loss per epoch: 0.07046896
# Validation
# Average Validation loss per epoch: 0.08774691
# Training
# [16] average loss per epoch: 0.06729882
# Validation
# Average Validation loss per epoch: 0.08779791
# Training
# [17] average loss per epoch: 0.06446643
# Validation
# Average Validation loss per epoch: 0.08878114
# Training
# [18] average loss per epoch: 0.06305673
# Validation
# Average Validation loss per epoch: 0.08868222
# Training
# [19] average loss per epoch: 0.06176170
# Validation
# Average Validation loss per epoch: 0.08740462
# Training
# [20] average loss per epoch: 0.05992064
# Validation
# Average Validation loss per epoch: 0.08671293
# Training
# [21] average loss per epoch: 0.05845824
# Validation
# Average Validation loss per epoch: 0.08642723
# Training
# [22] average loss per epoch: 0.05765809
# Validation
# Average Validation loss per epoch: 0.08571259
# Training
# [23] average loss per epoch: 0.05679841
# Validation
# Average Validation loss per epoch: 0.08509356
# Training
# [24] average loss per epoch: 0.05591061
# Validation
# Average Validation loss per epoch: 0.08492454
# Training
# [25] average loss per epoch: 0.05530813
# Validation
# Average Validation loss per epoch: 0.08471321
# Training
# [26] average loss per epoch: 0.05477664
# Validation
# Average Validation loss per epoch: 0.08440071
# Training
# [27] average loss per epoch: 0.05417976
# Validation
# Average Validation loss per epoch: 0.08428698
# Training
# [28] average loss per epoch: 0.05368888
# Validation
# Average Validation loss per epoch: 0.08420243
# Training
# [29] average loss per epoch: 0.05328453
# Validation
# Average Validation loss per epoch: 0.08401100
# Training
# [30] average loss per epoch: 0.05286469
# Validation
# Average Validation loss per epoch: 0.08386921
# Training
# [31] average loss per epoch: 0.05249041
# Validation
# Average Validation loss per epoch: 0.08375008
# Training
# [32] average loss per epoch: 0.05217388
# Validation
# Average Validation loss per epoch: 0.08357265
# Training
# [33] average loss per epoch: 0.05186111
# Validation
# Average Validation loss per epoch: 0.08341646
# Training
# [34] average loss per epoch: 0.05157228
# Validation
# Average Validation loss per epoch: 0.08328521
# Training
# [35] average loss per epoch: 0.05131585
# Validation
# Average Validation loss per epoch: 0.08313414
# Training
# [36] average loss per epoch: 0.05106493
# Validation
# Average Validation loss per epoch: 0.08299781
# Training
# [37] average loss per epoch: 0.05082781
# Validation
# Average Validation loss per epoch: 0.08287381
# Training
# [38] average loss per epoch: 0.05060794
# Validation
# Average Validation loss per epoch: 0.08273789
# Training
# [39] average loss per epoch: 0.05039339
# Validation
# Average Validation loss per epoch: 0.08260668
# Training
# [40] average loss per epoch: 0.05018928
# Validation
# Average Validation loss per epoch: 0.08247619
# Training
# [41] average loss per epoch: 0.04999586
# Validation
# Average Validation loss per epoch: 0.08233812
# Training
# [42] average loss per epoch: 0.04980779
# Validation
# Average Validation loss per epoch: 0.08220260
# Training
# [43] average loss per epoch: 0.04962796
# Validation
# Average Validation loss per epoch: 0.08206601
# Training
# [44] average loss per epoch: 0.04945478
# Validation
# Average Validation loss per epoch: 0.08192652
# Training
# [45] average loss per epoch: 0.04928621
# Validation
# Average Validation loss per epoch: 0.08178853
# Training
# [46] average loss per epoch: 0.04912351
# Validation
# Average Validation loss per epoch: 0.08164823
# Training
# [47] average loss per epoch: 0.04896510
# Validation
# Average Validation loss per epoch: 0.08150613
# Training
# [48] average loss per epoch: 0.04881073
# Validation
# Average Validation loss per epoch: 0.08136315
# Training
# [49] average loss per epoch: 0.04866062
# Validation
# Average Validation loss per epoch: 0.08121735
# Training
# [50] average loss per epoch: 0.04851388
# Validation
# Average Validation loss per epoch: 0.08107016
# Training
# [51] average loss per epoch: 0.04837063
# Validation
# Average Validation loss per epoch: 0.08092116
# Training
# [52] average loss per epoch: 0.04823054
# Validation
# Average Validation loss per epoch: 0.08077004
# Training
# [53] average loss per epoch: 0.04809323
# Validation
# Average Validation loss per epoch: 0.08061745
# Training
# [54] average loss per epoch: 0.04795873
# Validation
# Average Validation loss per epoch: 0.08046281
# Training
# [55] average loss per epoch: 0.04782666
# Validation
# Average Validation loss per epoch: 0.08030643
# Training
# [56] average loss per epoch: 0.04769702
# Validation
# Average Validation loss per epoch: 0.08014808
# Training
# [57] average loss per epoch: 0.04756959
# Validation
# Average Validation loss per epoch: 0.07998772
# Training
# [58] average loss per epoch: 0.04744425
# Validation
# Average Validation loss per epoch: 0.07982566
# Training
# [59] average loss per epoch: 0.04732094
# Validation
# Average Validation loss per epoch: 0.07966161
# Training
# [60] average loss per epoch: 0.04719949
# Validation
# Average Validation loss per epoch: 0.07949585
# Training
# [61] average loss per epoch: 0.04707983
# Validation
# Average Validation loss per epoch: 0.07932820
# Training
# [62] average loss per epoch: 0.04696183
# Validation
# Average Validation loss per epoch: 0.07915888
# Training
# [63] average loss per epoch: 0.04684545
# Validation
# Average Validation loss per epoch: 0.07898774
# Training
# [64] average loss per epoch: 0.04673060
# Validation
# Average Validation loss per epoch: 0.07881495
# Training
# [65] average loss per epoch: 0.04661715
# Validation
# Average Validation loss per epoch: 0.07864051
# Training
# [66] average loss per epoch: 0.04650510
# Validation
# Average Validation loss per epoch: 0.07846438
# Training
# [67] average loss per epoch: 0.04639434
# Validation
# Average Validation loss per epoch: 0.07828670
# Training
# [68] average loss per epoch: 0.04628482
# Validation
# Average Validation loss per epoch: 0.07810749
# Training
# [69] average loss per epoch: 0.04617645
# Validation
# Average Validation loss per epoch: 0.07792678
# Training
# [70] average loss per epoch: 0.04606920
# Validation
# Average Validation loss per epoch: 0.07774469
# Training
# [71] average loss per epoch: 0.04596301
# Validation
# Average Validation loss per epoch: 0.07756116
# Training
# [72] average loss per epoch: 0.04585782
# Validation
# Average Validation loss per epoch: 0.07737633
# Training
# [73] average loss per epoch: 0.04575356
# Validation
# Average Validation loss per epoch: 0.07719019
# Training
# [74] average loss per epoch: 0.04565019
# Validation
# Average Validation loss per epoch: 0.07700287
# Training
# [75] average loss per epoch: 0.04554766
# Validation
# Average Validation loss per epoch: 0.07681441
# Training
# [76] average loss per epoch: 0.04544593
# Validation
# Average Validation loss per epoch: 0.07662478
# Training
# [77] average loss per epoch: 0.04534493
# Validation
# Average Validation loss per epoch: 0.07643420
# Training
# [78] average loss per epoch: 0.04524464
# Validation
# Average Validation loss per epoch: 0.07624262
# Training
# [79] average loss per epoch: 0.04514498
# Validation
# Average Validation loss per epoch: 0.07605008
# Training
# [80] average loss per epoch: 0.04504596
# Validation
# Average Validation loss per epoch: 0.07585676
# Training
# [81] average loss per epoch: 0.04494748
# Validation
# Average Validation loss per epoch: 0.07566267
# Training
# [82] average loss per epoch: 0.04484956
# Validation
# Average Validation loss per epoch: 0.07546783
# Training
# [83] average loss per epoch: 0.04475213
# Validation
# Average Validation loss per epoch: 0.07527234
# Training
# [84] average loss per epoch: 0.04465513
# Validation
# Average Validation loss per epoch: 0.07507630
# Training
# [85] average loss per epoch: 0.04455856
# Validation
# Average Validation loss per epoch: 0.07487976
# Training
# [86] average loss per epoch: 0.04446239
# Validation
# Average Validation loss per epoch: 0.07468279
# Training
# [87] average loss per epoch: 0.04436657
# Validation
# Average Validation loss per epoch: 0.07448544
# Training
# [88] average loss per epoch: 0.04427107
# Validation
# Average Validation loss per epoch: 0.07428773
# Training
# [89] average loss per epoch: 0.04417586
# Validation
# Average Validation loss per epoch: 0.07408988
# Training
# [90] average loss per epoch: 0.04408093
# Validation
# Average Validation loss per epoch: 0.07389180
# Training
# [91] average loss per epoch: 0.04398623
# Validation
# Average Validation loss per epoch: 0.07369363
# Training
# [92] average loss per epoch: 0.04389177
# Validation
# Average Validation loss per epoch: 0.07349540
# Training
# [93] average loss per epoch: 0.04379749
# Validation
# Average Validation loss per epoch: 0.07329717
# Training
# [94] average loss per epoch: 0.04370338
# Validation
# Average Validation loss per epoch: 0.07309896
# Training
# [95] average loss per epoch: 0.04360944
# Validation
# Average Validation loss per epoch: 0.07290091
# Training
# [96] average loss per epoch: 0.04351563
# Validation
# Average Validation loss per epoch: 0.07270296
# Training
# [97] average loss per epoch: 0.04342194
# Validation
# Average Validation loss per epoch: 0.07250524
# Training
# [98] average loss per epoch: 0.04332835
# Validation
# Average Validation loss per epoch: 0.07230768
# Training
# [99] average loss per epoch: 0.04323486
# Validation
# Average Validation loss per epoch: 0.07211044
# Training
# [100] average loss per epoch: 0.04314144
# Validation
# Average Validation loss per epoch: 0.07191353
# Training
# [101] average loss per epoch: 0.04304809
# Validation
# Average Validation loss per epoch: 0.07171693
# Training
# [102] average loss per epoch: 0.04295480
# Validation
# Average Validation loss per epoch: 0.07152064
# Training
# [103] average loss per epoch: 0.04286154
# Validation
# Average Validation loss per epoch: 0.07132467
# Training
# [104] average loss per epoch: 0.04276833
# Validation
# Average Validation loss per epoch: 0.07112917
# Training
# [105] average loss per epoch: 0.04267515
# Validation
# Average Validation loss per epoch: 0.07093394
# Training
# [106] average loss per epoch: 0.04258203
# Validation
# Average Validation loss per epoch: 0.07073914
# Training
# [107] average loss per epoch: 0.04248887
# Validation
# Average Validation loss per epoch: 0.07054472
# Training
# [108] average loss per epoch: 0.04239576
# Validation
# Average Validation loss per epoch: 0.07035058
# Training
# [109] average loss per epoch: 0.04230266
# Validation
# Average Validation loss per epoch: 0.07015690
# Training
# [110] average loss per epoch: 0.04220956
# Validation
# Average Validation loss per epoch: 0.06996353
# Training
# [111] average loss per epoch: 0.04211645
# Validation
# Average Validation loss per epoch: 0.06977051
# Training
# [112] average loss per epoch: 0.04202336
# Validation
# Average Validation loss per epoch: 0.06957775
# Training
# [113] average loss per epoch: 0.04193028
# Validation
# Average Validation loss per epoch: 0.06938533
# Training
# [114] average loss per epoch: 0.04183719
# Validation
# Average Validation loss per epoch: 0.06919306
# Training
# [115] average loss per epoch: 0.04174411
# Validation
# Average Validation loss per epoch: 0.06900109
# Training
# [116] average loss per epoch: 0.04165099
# Validation
# Average Validation loss per epoch: 0.06880937
# Training
# [117] average loss per epoch: 0.04155791
# Validation
# Average Validation loss per epoch: 0.06861784
# Training
# [118] average loss per epoch: 0.04146481
# Validation
# Average Validation loss per epoch: 0.06842643
# Training
# [119] average loss per epoch: 0.04137171
# Validation
# Average Validation loss per epoch: 0.06823520
# Training
# [120] average loss per epoch: 0.04127861
# Validation
# Average Validation loss per epoch: 0.06804403
# Training
# [121] average loss per epoch: 0.04118553
# Validation
# Average Validation loss per epoch: 0.06785297
# Training
# [122] average loss per epoch: 0.04109243
# Validation
# Average Validation loss per epoch: 0.06766202
# Training
# [123] average loss per epoch: 0.04099934
# Validation
# Average Validation loss per epoch: 0.06747110
# Training
# [124] average loss per epoch: 0.04090628
# Validation
# Average Validation loss per epoch: 0.06728019
# Training
# [125] average loss per epoch: 0.04081321
# Validation
# Average Validation loss per epoch: 0.06708925
# Training
# [126] average loss per epoch: 0.04072016
# Validation
# Average Validation loss per epoch: 0.06689844
# Training
# [127] average loss per epoch: 0.04062712
# Validation
# Average Validation loss per epoch: 0.06670751
# Training
# [128] average loss per epoch: 0.04053410
# Validation
# Average Validation loss per epoch: 0.06651650
# Training
# [129] average loss per epoch: 0.04044110
# Validation
# Average Validation loss per epoch: 0.06632560
# Training
# [130] average loss per epoch: 0.04034811
# Validation
# Average Validation loss per epoch: 0.06613465
# Training
# [131] average loss per epoch: 0.04025514
# Validation
# Average Validation loss per epoch: 0.06594361
# Training
# [132] average loss per epoch: 0.04016222
# Validation
# Average Validation loss per epoch: 0.06575259
# Training
# [133] average loss per epoch: 0.04006931
# Validation
# Average Validation loss per epoch: 0.06556159
# Training
# [134] average loss per epoch: 0.03997642
# Validation
# Average Validation loss per epoch: 0.06537057
# Training
# [135] average loss per epoch: 0.03988356
# Validation
# Average Validation loss per epoch: 0.06517958
# Training
# [136] average loss per epoch: 0.03979073
# Validation
# Average Validation loss per epoch: 0.06498861
# Training
# [137] average loss per epoch: 0.03969793
# Validation
# Average Validation loss per epoch: 0.06479769
# Training
# [138] average loss per epoch: 0.03960516
# Validation
# Average Validation loss per epoch: 0.06460685
# Training
# [139] average loss per epoch: 0.03951243
# Validation
# Average Validation loss per epoch: 0.06441616
# Training
# [140] average loss per epoch: 0.03941972
# Validation
# Average Validation loss per epoch: 0.06422567
# Training
# [141] average loss per epoch: 0.03932705
# Validation
# Average Validation loss per epoch: 0.06403533
# Training
# [142] average loss per epoch: 0.03923440
# Validation
# Average Validation loss per epoch: 0.06384533
# Training
# [143] average loss per epoch: 0.03914177
# Validation
# Average Validation loss per epoch: 0.06365546
# Training
# [144] average loss per epoch: 0.03904919
# Validation
# Average Validation loss per epoch: 0.06346611
# Training
# [145] average loss per epoch: 0.03895661
# Validation
# Average Validation loss per epoch: 0.06327708
# Training
# [146] average loss per epoch: 0.03886405
# Validation
# Average Validation loss per epoch: 0.06308859
# Training
# [147] average loss per epoch: 0.03877153
# Validation
# Average Validation loss per epoch: 0.06290071
# Training
# [148] average loss per epoch: 0.03867903
# Validation
# Average Validation loss per epoch: 0.06271329
# Training
# [149] average loss per epoch: 0.03858653
# Validation
# Average Validation loss per epoch: 0.06252664
# Training
# [150] average loss per epoch: 0.03849403
# Validation
# Average Validation loss per epoch: 0.06234084
# Training
# [151] average loss per epoch: 0.03840155
# Validation
# Average Validation loss per epoch: 0.06215582
# Training
# [152] average loss per epoch: 0.03830909
# Validation
# Average Validation loss per epoch: 0.06197183
# Training
# [153] average loss per epoch: 0.03821661
# Validation
# Average Validation loss per epoch: 0.06178878
# Training
# [154] average loss per epoch: 0.03812415
# Validation
# Average Validation loss per epoch: 0.06160703
# Training
# [155] average loss per epoch: 0.03803167
# Validation
# Average Validation loss per epoch: 0.06142637
# Training
# [156] average loss per epoch: 0.03793921
# Validation
# Average Validation loss per epoch: 0.06124716
# Training
# [157] average loss per epoch: 0.03784674
# Validation
# Average Validation loss per epoch: 0.06106931
# Training
# [158] average loss per epoch: 0.03775427
# Validation
# Average Validation loss per epoch: 0.06089308
# Training
# [159] average loss per epoch: 0.03766178
# Validation
# Average Validation loss per epoch: 0.06071847
# Training
# [160] average loss per epoch: 0.03756931
# Validation
# Average Validation loss per epoch: 0.06054568
# Training
# [161] average loss per epoch: 0.03747685
# Validation
# Average Validation loss per epoch: 0.06037472
# Training
# [162] average loss per epoch: 0.03738439
# Validation
# Average Validation loss per epoch: 0.06020575
# Training
# [163] average loss per epoch: 0.03729192
# Validation
# Average Validation loss per epoch: 0.06003885
# Training
# [164] average loss per epoch: 0.03719951
# Validation
# Average Validation loss per epoch: 0.05987421
# Training
# [165] average loss per epoch: 0.03710711
# Validation
# Average Validation loss per epoch: 0.05971182
# Training
# [166] average loss per epoch: 0.03701476
# Validation
# Average Validation loss per epoch: 0.05955185
# Training
# [167] average loss per epoch: 0.03692246
# Validation
# Average Validation loss per epoch: 0.05939431
# Training
# [168] average loss per epoch: 0.03683024
# Validation
# Average Validation loss per epoch: 0.05923938
# Training
# [169] average loss per epoch: 0.03673807
# Validation
# Average Validation loss per epoch: 0.05908717
# Training
# [170] average loss per epoch: 0.03664599
# Validation
# Average Validation loss per epoch: 0.05893767
# Training
# [171] average loss per epoch: 0.03655403
# Validation
# Average Validation loss per epoch: 0.05879101
# Training
# [172] average loss per epoch: 0.03646221
# Validation
# Average Validation loss per epoch: 0.05864733
# Training
# [173] average loss per epoch: 0.03637053
# Validation
# Average Validation loss per epoch: 0.05850654
# Training
# [174] average loss per epoch: 0.03627901
# Validation
# Average Validation loss per epoch: 0.05836885
# Training
# [175] average loss per epoch: 0.03618770
# Validation
# Average Validation loss per epoch: 0.05823426
# Training
# [176] average loss per epoch: 0.03609661
# Validation
# Average Validation loss per epoch: 0.05810277
# Training
# [177] average loss per epoch: 0.03600572
# Validation
# Average Validation loss per epoch: 0.05797447
# Training
# [178] average loss per epoch: 0.03591510
# Validation
# Average Validation loss per epoch: 0.05784943
# Training
# [179] average loss per epoch: 0.03582475
# Validation
# Average Validation loss per epoch: 0.05772759
# Training
# [180] average loss per epoch: 0.03573473
# Validation
# Average Validation loss per epoch: 0.05760898
# Training
# [181] average loss per epoch: 0.03564502
# Validation
# Average Validation loss per epoch: 0.05749368
# Training
# [182] average loss per epoch: 0.03555565
# Validation
# Average Validation loss per epoch: 0.05738164
# Training
# [183] average loss per epoch: 0.03546664
# Validation
# Average Validation loss per epoch: 0.05727282
# Training
# [184] average loss per epoch: 0.03537800
# Validation
# Average Validation loss per epoch: 0.05716728
# Training
# [185] average loss per epoch: 0.03528979
# Validation
# Average Validation loss per epoch: 0.05706495
# Training
# [186] average loss per epoch: 0.03520201
# Validation
# Average Validation loss per epoch: 0.05696583
# Training
# [187] average loss per epoch: 0.03511465
# Validation
# Average Validation loss per epoch: 0.05686987
# Training
# [188] average loss per epoch: 0.03502775
# Validation
# Average Validation loss per epoch: 0.05677704
# Training
# [189] average loss per epoch: 0.03494133
# Validation
# Average Validation loss per epoch: 0.05668728
# Training
# [190] average loss per epoch: 0.03485538
# Validation
# Average Validation loss per epoch: 0.05660054
# Training
# [191] average loss per epoch: 0.03476992
# Validation
# Average Validation loss per epoch: 0.05651685
# Training
# [192] average loss per epoch: 0.03468498
# Validation
# Average Validation loss per epoch: 0.05643603
# Training
# [193] average loss per epoch: 0.03460055
# Validation
# Average Validation loss per epoch: 0.05635809
# Training
# [194] average loss per epoch: 0.03451664
# Validation
# Average Validation loss per epoch: 0.05628293
# Training
# [195] average loss per epoch: 0.03443327
# Validation
# Average Validation loss per epoch: 0.05621052
# Training
# [196] average loss per epoch: 0.03435042
# Validation
# Average Validation loss per epoch: 0.05614071
# Training
# [197] average loss per epoch: 0.03426813
# Validation
# Average Validation loss per epoch: 0.05607355
# Training
# [198] average loss per epoch: 0.03418638
# Validation
# Average Validation loss per epoch: 0.05600886
# Training
# [199] average loss per epoch: 0.03410518
# Validation
# Average Validation loss per epoch: 0.05594655
# Training
# [200] average loss per epoch: 0.03402451
# Validation
# Average Validation loss per epoch: 0.05588665
# Training
# [201] average loss per epoch: 0.03394439
# Validation
# Average Validation loss per epoch: 0.05582900
# Training
# [202] average loss per epoch: 0.03386485
# Validation
# Average Validation loss per epoch: 0.05577355
# Training
# [203] average loss per epoch: 0.03378586
# Validation
# Average Validation loss per epoch: 0.05572018
# Training
# [204] average loss per epoch: 0.03370739
# Validation
# Average Validation loss per epoch: 0.05566884
# Training
# [205] average loss per epoch: 0.03362947
# Validation
# Average Validation loss per epoch: 0.05561949
# Training
# [206] average loss per epoch: 0.03355209
# Validation
# Average Validation loss per epoch: 0.05557204
# Training
# [207] average loss per epoch: 0.03347524
# Validation
# Average Validation loss per epoch: 0.05552632
# Training
# [208] average loss per epoch: 0.03339894
# Validation
# Average Validation loss per epoch: 0.05548239
# Training
# [209] average loss per epoch: 0.03332317
# Validation
# Average Validation loss per epoch: 0.05544003
# Training
# [210] average loss per epoch: 0.03324792
# Validation
# Average Validation loss per epoch: 0.05539928
# Training
# [211] average loss per epoch: 0.03317318
# Validation
# Average Validation loss per epoch: 0.05536005
# Training
# [212] average loss per epoch: 0.03309895
# Validation
# Average Validation loss per epoch: 0.05532222
# Training
# [213] average loss per epoch: 0.03302519
# Validation
# Average Validation loss per epoch: 0.05528576
# Training
# [214] average loss per epoch: 0.03295193
# Validation
# Average Validation loss per epoch: 0.05525063
# Training
# [215] average loss per epoch: 0.03287921
# Validation
# Average Validation loss per epoch: 0.05521666
# Training
# [216] average loss per epoch: 0.03280695
# Validation
# Average Validation loss per epoch: 0.05518385
# Training
# [217] average loss per epoch: 0.03273515
# Validation
# Average Validation loss per epoch: 0.05515211
# Training
# [218] average loss per epoch: 0.03266382
# Validation
# Average Validation loss per epoch: 0.05512144
# Training
# [219] average loss per epoch: 0.03259296
# Validation
# Average Validation loss per epoch: 0.05509175
# Training
# [220] average loss per epoch: 0.03252252
# Validation
# Average Validation loss per epoch: 0.05506301
# Training
# [221] average loss per epoch: 0.03245251
# Validation
# Average Validation loss per epoch: 0.05503509
# Training
# [222] average loss per epoch: 0.03238298
# Validation
# Average Validation loss per epoch: 0.05500790
# Training
# [223] average loss per epoch: 0.03231385
# Validation
# Average Validation loss per epoch: 0.05498154
# Training
# [224] average loss per epoch: 0.03224514
# Validation
# Average Validation loss per epoch: 0.05495593
# Training
# [225] average loss per epoch: 0.03217682
# Validation
# Average Validation loss per epoch: 0.05493094
# Training
# [226] average loss per epoch: 0.03210890
# Validation
# Average Validation loss per epoch: 0.05490660
# Training
# [227] average loss per epoch: 0.03204139
# Validation
# Average Validation loss per epoch: 0.05488278
# Training
# [228] average loss per epoch: 0.03197430
# Validation
# Average Validation loss per epoch: 0.05485948
# Training
# [229] average loss per epoch: 0.03190757
# Validation
# Average Validation loss per epoch: 0.05483672
# Training
# [230] average loss per epoch: 0.03184120
# Validation
# Average Validation loss per epoch: 0.05481435
# Training
# [231] average loss per epoch: 0.03177520
# Validation
# Average Validation loss per epoch: 0.05479250
# Training
# [232] average loss per epoch: 0.03170955
# Validation
# Average Validation loss per epoch: 0.05477101
# Training
# [233] average loss per epoch: 0.03164427
# Validation
# Average Validation loss per epoch: 0.05474989
# Training
# [234] average loss per epoch: 0.03157935
# Validation
# Average Validation loss per epoch: 0.05472914
# Training
# [235] average loss per epoch: 0.03151478
# Validation
# Average Validation loss per epoch: 0.05470863
# Training
# [236] average loss per epoch: 0.03145057
# Validation
# Average Validation loss per epoch: 0.05468840
# Training
# [237] average loss per epoch: 0.03138670
# Validation
# Average Validation loss per epoch: 0.05466845
# Training
# [238] average loss per epoch: 0.03132315
# Validation
# Average Validation loss per epoch: 0.05464876
# Training
# [239] average loss per epoch: 0.03125994
# Validation
# Average Validation loss per epoch: 0.05462930
# Training
# [240] average loss per epoch: 0.03119707
# Validation
# Average Validation loss per epoch: 0.05461005
# Training
# [241] average loss per epoch: 0.03113453
# Validation
# Average Validation loss per epoch: 0.05459096
# Training
# [242] average loss per epoch: 0.03107231
# Validation
# Average Validation loss per epoch: 0.05457213
# Training
# [243] average loss per epoch: 0.03101043
# Validation
# Average Validation loss per epoch: 0.05455337
# Training
# [244] average loss per epoch: 0.03094888
# Validation
# Average Validation loss per epoch: 0.05453478
# Training
# [245] average loss per epoch: 0.03088766
# Validation
# Average Validation loss per epoch: 0.05451629
# Training
# [246] average loss per epoch: 0.03082676
# Validation
# Average Validation loss per epoch: 0.05449796
# Training
# [247] average loss per epoch: 0.03076618
# Validation
# Average Validation loss per epoch: 0.05447980
# Training
# [248] average loss per epoch: 0.03070590
# Validation
# Average Validation loss per epoch: 0.05446171
# Training
# [249] average loss per epoch: 0.03064598
# Validation
# Average Validation loss per epoch: 0.05444375
# Training
# [250] average loss per epoch: 0.03058636
# Validation
# Average Validation loss per epoch: 0.05442590
# Training
# [251] average loss per epoch: 0.03052707
# Validation
# Average Validation loss per epoch: 0.05440816
# Training
# [252] average loss per epoch: 0.03046809
# Validation
# Average Validation loss per epoch: 0.05439050
# Training
# [253] average loss per epoch: 0.03040946
# Validation
# Average Validation loss per epoch: 0.05437291
# Training
# [254] average loss per epoch: 0.03035113
# Validation
# Average Validation loss per epoch: 0.05435547
# Training
# [255] average loss per epoch: 0.03029314
# Validation
# Average Validation loss per epoch: 0.05433803
# Training
# [256] average loss per epoch: 0.03023544
# Validation
# Average Validation loss per epoch: 0.05432080
# Training
# [257] average loss per epoch: 0.03017805
# Validation
# Average Validation loss per epoch: 0.05430360
# Training
# [258] average loss per epoch: 0.03012098
# Validation
# Average Validation loss per epoch: 0.05428655
# Training
# [259] average loss per epoch: 0.03006424
# Validation
# Average Validation loss per epoch: 0.05426954
# Training
# [260] average loss per epoch: 0.03000783
# Validation
# Average Validation loss per epoch: 0.05425265
# Training
# [261] average loss per epoch: 0.02995173
# Validation
# Average Validation loss per epoch: 0.05423585
# Training
# [262] average loss per epoch: 0.02989596
# Validation
# Average Validation loss per epoch: 0.05421915
# Training
# [263] average loss per epoch: 0.02984048
# Validation
# Average Validation loss per epoch: 0.05420253
# Training
# [264] average loss per epoch: 0.02978529
# Validation
# Average Validation loss per epoch: 0.05418605
# Training
# [265] average loss per epoch: 0.02973041
# Validation
# Average Validation loss per epoch: 0.05416970
# Training
# [266] average loss per epoch: 0.02967587
# Validation
# Average Validation loss per epoch: 0.05415344
# Training
# [267] average loss per epoch: 0.02962164
# Validation
# Average Validation loss per epoch: 0.05413730
# Training
# [268] average loss per epoch: 0.02956770
# Validation
# Average Validation loss per epoch: 0.05412126
# Training
# [269] average loss per epoch: 0.02951407
# Validation
# Average Validation loss per epoch: 0.05410539
# Training
# [270] average loss per epoch: 0.02946074
# Validation
# Average Validation loss per epoch: 0.05408961
# Training
# [271] average loss per epoch: 0.02940771
# Validation
# Average Validation loss per epoch: 0.05407398
# Training
# [272] average loss per epoch: 0.02935496
# Validation
# Average Validation loss per epoch: 0.05405849
# Training
# [273] average loss per epoch: 0.02930249
# Validation
# Average Validation loss per epoch: 0.05404316
# Training
# [274] average loss per epoch: 0.02925034
# Validation
# Average Validation loss per epoch: 0.05402799
# Training
# [275] average loss per epoch: 0.02919848
# Validation
# Average Validation loss per epoch: 0.05401291
# Training
# [276] average loss per epoch: 0.02914690
# Validation
# Average Validation loss per epoch: 0.05399805
# Training
# [277] average loss per epoch: 0.02909564
# Validation
# Average Validation loss per epoch: 0.05398331
# Training
# [278] average loss per epoch: 0.02904465
# Validation
# Average Validation loss per epoch: 0.05396879
# Training
# [279] average loss per epoch: 0.02899394
# Validation
# Average Validation loss per epoch: 0.05395437
# Training
# [280] average loss per epoch: 0.02894348
# Validation
# Average Validation loss per epoch: 0.05394013
# Training
# [281] average loss per epoch: 0.02889332
# Validation
# Average Validation loss per epoch: 0.05392614
# Training
# [282] average loss per epoch: 0.02884345
# Validation
# Average Validation loss per epoch: 0.05391225
# Training
# [283] average loss per epoch: 0.02879385
# Validation
# Average Validation loss per epoch: 0.05389860
# Training
# [284] average loss per epoch: 0.02874450
# Validation
# Average Validation loss per epoch: 0.05388514
# Training
# [285] average loss per epoch: 0.02869546
# Validation
# Average Validation loss per epoch: 0.05387183
# Training
# [286] average loss per epoch: 0.02864666
# Validation
# Average Validation loss per epoch: 0.05385876
# Training
# [287] average loss per epoch: 0.02859812
# Validation
# Average Validation loss per epoch: 0.05384592
# Training
# [288] average loss per epoch: 0.02854983
# Validation
# Average Validation loss per epoch: 0.05383326
# Training
# [289] average loss per epoch: 0.02850183
# Validation
# Average Validation loss per epoch: 0.05382080
# Training
# [290] average loss per epoch: 0.02845409
# Validation
# Average Validation loss per epoch: 0.05380855
# Training
# [291] average loss per epoch: 0.02840661
# Validation
# Average Validation loss per epoch: 0.05379650
# Training
# [292] average loss per epoch: 0.02835938
# Validation
# Average Validation loss per epoch: 0.05378468
# Training
# [293] average loss per epoch: 0.02831240
# Validation
# Average Validation loss per epoch: 0.05377307
# Training
# [294] average loss per epoch: 0.02826568
# Validation
# Average Validation loss per epoch: 0.05376166
# Training
# [295] average loss per epoch: 0.02821921
# Validation
# Average Validation loss per epoch: 0.05375051
# Training
# [296] average loss per epoch: 0.02817298
# Validation
# Average Validation loss per epoch: 0.05373955
# Training
# [297] average loss per epoch: 0.02812701
# Validation
# Average Validation loss per epoch: 0.05372885
# Training
# [298] average loss per epoch: 0.02808127
# Validation
# Average Validation loss per epoch: 0.05371836
# Training
# [299] average loss per epoch: 0.02803578
# Validation
# Average Validation loss per epoch: 0.05370804
# Training
# [300] average loss per epoch: 0.02799053
# Validation
# Average Validation loss per epoch: 0.05369798
# Training
# [301] average loss per epoch: 0.02794552
# Validation
# Average Validation loss per epoch: 0.05368820
# Training
# [302] average loss per epoch: 0.02790074
# Validation
# Average Validation loss per epoch: 0.05367864
# Training
# [303] average loss per epoch: 0.02785617
# Validation
# Average Validation loss per epoch: 0.05366930
# Training
# [304] average loss per epoch: 0.02781188
# Validation
# Average Validation loss per epoch: 0.05366014
# Training
# [305] average loss per epoch: 0.02776783
# Validation
# Average Validation loss per epoch: 0.05365125
# Training
# [306] average loss per epoch: 0.02772401
# Validation
# Average Validation loss per epoch: 0.05364255
# Training
# [307] average loss per epoch: 0.02768040
# Validation
# Average Validation loss per epoch: 0.05363410
# Training
# [308] average loss per epoch: 0.02763704
# Validation
# Average Validation loss per epoch: 0.05362589
# Training
# [309] average loss per epoch: 0.02759389
# Validation
# Average Validation loss per epoch: 0.05361784
# Training
# [310] average loss per epoch: 0.02755096
# Validation
# Average Validation loss per epoch: 0.05361005
# Training
# [311] average loss per epoch: 0.02750824
# Validation
# Average Validation loss per epoch: 0.05360248
# Training
# [312] average loss per epoch: 0.02746576
# Validation
# Average Validation loss per epoch: 0.05359520
# Training
# [313] average loss per epoch: 0.02742348
# Validation
# Average Validation loss per epoch: 0.05358803
# Training
# [314] average loss per epoch: 0.02738144
# Validation
# Average Validation loss per epoch: 0.05358116
# Training
# [315] average loss per epoch: 0.02733962
# Validation
# Average Validation loss per epoch: 0.05357448
# Training
# [316] average loss per epoch: 0.02729803
# Validation
# Average Validation loss per epoch: 0.05356799
# Training
# [317] average loss per epoch: 0.02725664
# Validation
# Average Validation loss per epoch: 0.05356174
# Training
# [318] average loss per epoch: 0.02721548
# Validation
# Average Validation loss per epoch: 0.05355564
# Training
# [319] average loss per epoch: 0.02717454
# Validation
# Average Validation loss per epoch: 0.05354977
# Training
# [320] average loss per epoch: 0.02713377
# Validation
# Average Validation loss per epoch: 0.05354409
# Training
# [321] average loss per epoch: 0.02709323
# Validation
# Average Validation loss per epoch: 0.05353862
# Training
# [322] average loss per epoch: 0.02705289
# Validation
# Average Validation loss per epoch: 0.05353332
# Training
# [323] average loss per epoch: 0.02701277
# Validation
# Average Validation loss per epoch: 0.05352826
# Training
# [324] average loss per epoch: 0.02697284
# Validation
# Average Validation loss per epoch: 0.05352336
# Training
# [325] average loss per epoch: 0.02693313
# Validation
# Average Validation loss per epoch: 0.05351864
# Training
# [326] average loss per epoch: 0.02689361
# Validation
# Average Validation loss per epoch: 0.05351413
# Training
# [327] average loss per epoch: 0.02685431
# Validation
# Average Validation loss per epoch: 0.05350980
# Training
# [328] average loss per epoch: 0.02681519
# Validation
# Average Validation loss per epoch: 0.05350564
# Training
# [329] average loss per epoch: 0.02677631
# Validation
# Average Validation loss per epoch: 0.05350158
# Training
# [330] average loss per epoch: 0.02673761
# Validation
# Average Validation loss per epoch: 0.05349767
# Training
# [331] average loss per epoch: 0.02669911
# Validation
# Average Validation loss per epoch: 0.05349395
# Training
# [332] average loss per epoch: 0.02666080
# Validation
# Average Validation loss per epoch: 0.05349034
# Training
# [333] average loss per epoch: 0.02662269
# Validation
# Average Validation loss per epoch: 0.05348692
# Training
# [334] average loss per epoch: 0.02658475
# Validation
# Average Validation loss per epoch: 0.05348368
# Training
# [335] average loss per epoch: 0.02654702
# Validation
# Average Validation loss per epoch: 0.05348057
# Training
# [336] average loss per epoch: 0.02650948
# Validation
# Average Validation loss per epoch: 0.05347753
# Training
# [337] average loss per epoch: 0.02647214
# Validation
# Average Validation loss per epoch: 0.05347466
# Training
# [338] average loss per epoch: 0.02643498
# Validation
# Average Validation loss per epoch: 0.05347190
# Training
# [339] average loss per epoch: 0.02639803
# Validation
# Average Validation loss per epoch: 0.05346930
# Training
# [340] average loss per epoch: 0.02636126
# Validation
# Average Validation loss per epoch: 0.05346679
# Training
# [341] average loss per epoch: 0.02632469
# Validation
# Average Validation loss per epoch: 0.05346429
# Training
# [342] average loss per epoch: 0.02628829
# Validation
# Average Validation loss per epoch: 0.05346197
# Training
# [343] average loss per epoch: 0.02625208
# Validation
# Average Validation loss per epoch: 0.05345974
# Training
# [344] average loss per epoch: 0.02621605
# Validation
# Average Validation loss per epoch: 0.05345757
# Training
# [345] average loss per epoch: 0.02618022
# Validation
# Average Validation loss per epoch: 0.05345551
# Training
# [346] average loss per epoch: 0.02614458
# Validation
# Average Validation loss per epoch: 0.05345349
# Training
# [347] average loss per epoch: 0.02610910
# Validation
# Average Validation loss per epoch: 0.05345153
# Training
# [348] average loss per epoch: 0.02607382
# Validation
# Average Validation loss per epoch: 0.05344966
# Training
# [349] average loss per epoch: 0.02603869
# Validation
# Average Validation loss per epoch: 0.05344783
# Training
# [350] average loss per epoch: 0.02600377
# Validation
# Average Validation loss per epoch: 0.05344605
# Training
# [351] average loss per epoch: 0.02596903
# Validation
# Average Validation loss per epoch: 0.05344428
# Training
# [352] average loss per epoch: 0.02593446
# Validation
# Average Validation loss per epoch: 0.05344255
# Training
# [353] average loss per epoch: 0.02590007
# Validation
# Average Validation loss per epoch: 0.05344082
# Training
# [354] average loss per epoch: 0.02586585
# Validation
# Average Validation loss per epoch: 0.05343914
# Training
# [355] average loss per epoch: 0.02583181
# Validation
# Average Validation loss per epoch: 0.05343753
# Training
# [356] average loss per epoch: 0.02579795
# Validation
# Average Validation loss per epoch: 0.05343581
# Training
# [357] average loss per epoch: 0.02576425
# Validation
# Average Validation loss per epoch: 0.05343422
# Training
# [358] average loss per epoch: 0.02573072
# Validation
# Average Validation loss per epoch: 0.05343257
# Training
# [359] average loss per epoch: 0.02569739
# Validation
# Average Validation loss per epoch: 0.05343089
# Training
# [360] average loss per epoch: 0.02566423
# Validation
# Average Validation loss per epoch: 0.05342913
# Training
# [361] average loss per epoch: 0.02563125
# Validation
# Average Validation loss per epoch: 0.05342739
# Training
# [362] average loss per epoch: 0.02559842
# Validation
# Average Validation loss per epoch: 0.05342558
# Training
# [363] average loss per epoch: 0.02556578
# Validation
# Average Validation loss per epoch: 0.05342382
# Training
# [364] average loss per epoch: 0.02553330
# Validation
# Average Validation loss per epoch: 0.05342187
# Training
# [365] average loss per epoch: 0.02550099
# Validation
# Average Validation loss per epoch: 0.05341991
# Training
# [366] average loss per epoch: 0.02546884
# Validation
# Average Validation loss per epoch: 0.05341789
# Training
# [367] average loss per epoch: 0.02543686
# Validation
# Average Validation loss per epoch: 0.05341576
# Training
# [368] average loss per epoch: 0.02540504
# Validation
# Average Validation loss per epoch: 0.05341363
# Training
# [369] average loss per epoch: 0.02537337
# Validation
# Average Validation loss per epoch: 0.05341136
# Training
# [370] average loss per epoch: 0.02534188
# Validation
# Average Validation loss per epoch: 0.05340897
# Training
# [371] average loss per epoch: 0.02531056
# Validation
# Average Validation loss per epoch: 0.05340647
# Training
# [372] average loss per epoch: 0.02527939
# Validation
# Average Validation loss per epoch: 0.05340391
# Training
# [373] average loss per epoch: 0.02524840
# Validation
# Average Validation loss per epoch: 0.05340122
# Training
# [374] average loss per epoch: 0.02521758
# Validation
# Average Validation loss per epoch: 0.05339844
# Training
# [375] average loss per epoch: 0.02518689
# Validation
# Average Validation loss per epoch: 0.05339548
# Training
# [376] average loss per epoch: 0.02515639
# Validation
# Average Validation loss per epoch: 0.05339241
# Training
# [377] average loss per epoch: 0.02512606
# Validation
# Average Validation loss per epoch: 0.05338913
# Training
# [378] average loss per epoch: 0.02509587
# Validation
# Average Validation loss per epoch: 0.05338569
# Training
# [379] average loss per epoch: 0.02506586
# Validation
# Average Validation loss per epoch: 0.05338208
# Training
# [380] average loss per epoch: 0.02503599
# Validation
# Average Validation loss per epoch: 0.05337832
# Training
# [381] average loss per epoch: 0.02500628
# Validation
# Average Validation loss per epoch: 0.05337441
# Training
# [382] average loss per epoch: 0.02497672
# Validation
# Average Validation loss per epoch: 0.05337021
# Training
# [383] average loss per epoch: 0.02494732
# Validation
# Average Validation loss per epoch: 0.05336586
# Training
# [384] average loss per epoch: 0.02491806
# Validation
# Average Validation loss per epoch: 0.05336140
# Training
# [385] average loss per epoch: 0.02488895
# Validation
# Average Validation loss per epoch: 0.05335660
# Training
# [386] average loss per epoch: 0.02485998
# Validation
# Average Validation loss per epoch: 0.05335171
# Training
# [387] average loss per epoch: 0.02483118
# Validation
# Average Validation loss per epoch: 0.05334657
# Training
# [388] average loss per epoch: 0.02480253
# Validation
# Average Validation loss per epoch: 0.05334121
# Training
# [389] average loss per epoch: 0.02477403
# Validation
# Average Validation loss per epoch: 0.05333566
# Training
# [390] average loss per epoch: 0.02474568
# Validation
# Average Validation loss per epoch: 0.05332985
# Training
# [391] average loss per epoch: 0.02471750
# Validation
# Average Validation loss per epoch: 0.05332380
# Training
# [392] average loss per epoch: 0.02468945
# Validation
# Average Validation loss per epoch: 0.05331748
# Training
# [393] average loss per epoch: 0.02466156
# Validation
# Average Validation loss per epoch: 0.05331090
# Training
# [394] average loss per epoch: 0.02463382
# Validation
# Average Validation loss per epoch: 0.05330401
# Training
# [395] average loss per epoch: 0.02460623
# Validation
# Average Validation loss per epoch: 0.05329688
# Training
# [396] average loss per epoch: 0.02457880
# Validation
# Average Validation loss per epoch: 0.05328944
# Training
# [397] average loss per epoch: 0.02455151
# Validation
# Average Validation loss per epoch: 0.05328170
# Training
# [398] average loss per epoch: 0.02452435
# Validation
# Average Validation loss per epoch: 0.05327364
# Training
# [399] average loss per epoch: 0.02449732
# Validation
# Average Validation loss per epoch: 0.05326531
# Training
# [400] average loss per epoch: 0.02447045
# Validation
# Average Validation loss per epoch: 0.05325671
# Training
# [401] average loss per epoch: 0.02444367
# Validation
# Average Validation loss per epoch: 0.05324779
# Training
# [402] average loss per epoch: 0.02441706
# Validation
# Average Validation loss per epoch: 0.05323858
# Training
# [403] average loss per epoch: 0.02439056
# Validation
# Average Validation loss per epoch: 0.05322908
# Training
# [404] average loss per epoch: 0.02436421
# Validation
# Average Validation loss per epoch: 0.05321928
# Training
# [405] average loss per epoch: 0.02433799
# Validation
# Average Validation loss per epoch: 0.05320917
# Training
# [406] average loss per epoch: 0.02431193
# Validation
# Average Validation loss per epoch: 0.05319878
# Training
# [407] average loss per epoch: 0.02428600
# Validation
# Average Validation loss per epoch: 0.05318801
# Training
# [408] average loss per epoch: 0.02426021
# Validation
# Average Validation loss per epoch: 0.05317682
# Training
# [409] average loss per epoch: 0.02423460
# Validation
# Average Validation loss per epoch: 0.05316538
# Training
# [410] average loss per epoch: 0.02420910
# Validation
# Average Validation loss per epoch: 0.05315357
# Training
# [411] average loss per epoch: 0.02418377
# Validation
# Average Validation loss per epoch: 0.05314133
# Training
# [412] average loss per epoch: 0.02415856
# Validation
# Average Validation loss per epoch: 0.05312876
# Training
# [413] average loss per epoch: 0.02413350
# Validation
# Average Validation loss per epoch: 0.05311577
# Training
# [414] average loss per epoch: 0.02410857
# Validation
# Average Validation loss per epoch: 0.05310240
# Training
# [415] average loss per epoch: 0.02408376
# Validation
# Average Validation loss per epoch: 0.05308867
# Training
# [416] average loss per epoch: 0.02405907
# Validation
# Average Validation loss per epoch: 0.05307453
# Training
# [417] average loss per epoch: 0.02403450
# Validation
# Average Validation loss per epoch: 0.05305998
# Training
# [418] average loss per epoch: 0.02401005
# Validation
# Average Validation loss per epoch: 0.05304502
# Training
# [419] average loss per epoch: 0.02398571
# Validation
# Average Validation loss per epoch: 0.05302974
# Training
# [420] average loss per epoch: 0.02396149
# Validation
# Average Validation loss per epoch: 0.05301414
# Training
# [421] average loss per epoch: 0.02393739
# Validation
# Average Validation loss per epoch: 0.05299811
# Training
# [422] average loss per epoch: 0.02391339
# Validation
# Average Validation loss per epoch: 0.05298172
# Training
# [423] average loss per epoch: 0.02388953
# Validation
# Average Validation loss per epoch: 0.05296509
# Training
# [424] average loss per epoch: 0.02386581
# Validation
# Average Validation loss per epoch: 0.05294792
# Training
# [425] average loss per epoch: 0.02384221
# Validation
# Average Validation loss per epoch: 0.05293043
# Training
# [426] average loss per epoch: 0.02381878
# Validation
# Average Validation loss per epoch: 0.05291248
# Training
# [427] average loss per epoch: 0.02379547
# Validation
# Average Validation loss per epoch: 0.05289419
# Training
# [428] average loss per epoch: 0.02377232
# Validation
# Average Validation loss per epoch: 0.05287539
# Training
# [429] average loss per epoch: 0.02374930
# Validation
# Average Validation loss per epoch: 0.05285614
# Training
# [430] average loss per epoch: 0.02372641
# Validation
# Average Validation loss per epoch: 0.05283648
# Training
# [431] average loss per epoch: 0.02370368
# Validation
# Average Validation loss per epoch: 0.05281629
# Training
# [432] average loss per epoch: 0.02368107
# Validation
# Average Validation loss per epoch: 0.05279570
# Training
# [433] average loss per epoch: 0.02365858
# Validation
# Average Validation loss per epoch: 0.05277450
# Training
# [434] average loss per epoch: 0.02363623
# Validation
# Average Validation loss per epoch: 0.05275294
# Training
# [435] average loss per epoch: 0.02361395
# Validation
# Average Validation loss per epoch: 0.05273084
# Training
# [436] average loss per epoch: 0.02359178
# Validation
# Average Validation loss per epoch: 0.05270829
# Training
# [437] average loss per epoch: 0.02356972
# Validation
# Average Validation loss per epoch: 0.05268533
# Training
# [438] average loss per epoch: 0.02354776
# Validation
# Average Validation loss per epoch: 0.05266191
# Training
# [439] average loss per epoch: 0.02352588
# Validation
# Average Validation loss per epoch: 0.05263812
# Training
# [440] average loss per epoch: 0.02350410
# Validation
# Average Validation loss per epoch: 0.05261390
# Training
# [441] average loss per epoch: 0.02348242
# Validation
# Average Validation loss per epoch: 0.05258924
# Training
# [442] average loss per epoch: 0.02346083
# Validation
# Average Validation loss per epoch: 0.05256427
# Training
# [443] average loss per epoch: 0.02343935
# Validation
# Average Validation loss per epoch: 0.05253892
# Training
# [444] average loss per epoch: 0.02341796
# Validation
# Average Validation loss per epoch: 0.05251310
# Training
# [445] average loss per epoch: 0.02339671
# Validation
# Average Validation loss per epoch: 0.05248687
# Training
# [446] average loss per epoch: 0.02337559
# Validation
# Average Validation loss per epoch: 0.05246024
# Training
# [447] average loss per epoch: 0.02335459
# Validation
# Average Validation loss per epoch: 0.05243316
# Training
# [448] average loss per epoch: 0.02333372
# Validation
# Average Validation loss per epoch: 0.05240564
# Training
# [449] average loss per epoch: 0.02331298
# Validation
# Average Validation loss per epoch: 0.05237757
# Training
# [450] average loss per epoch: 0.02329240
# Validation
# ...
# Training
# [852] average loss per epoch: 0.02213150
# Validation
# Average Validation loss per epoch: 0.05432819
# Training
# [853] average loss per epoch: 0.02325956
# Validation
# Average Validation loss per epoch: 0.04535193
# Training
# [854] average loss per epoch: 0.02169252
# Validation
# Average Validation loss per epoch: 0.04035176
# Training
# [855] average loss per epoch: 0.02044277
# Validation
# Average Validation loss per epoch: 0.03923167
# Training
# [856] average loss per epoch: 0.02109866
# Validation
# Average Validation loss per epoch: 0.03714510
# Training
# [857] average loss per epoch: 0.02143146
# Validation
# Average Validation loss per epoch: 0.03552058
# Training
# [858] average loss per epoch: 0.01968507
# Validation
# Average Validation loss per epoch: 0.04069407
# Training
# [859] average loss per epoch: 0.01800241
# Validation
# Average Validation loss per epoch: 0.05154460
# Training
# [860] average loss per epoch: 0.01960357
# Validation
# Average Validation loss per epoch: 0.05586602
# Training
# [861] average loss per epoch: 0.02252032
# Validation
# Average Validation loss per epoch: 0.04944126
# Training
# [862] average loss per epoch: 0.02247415
# Validation
# Average Validation loss per epoch: 0.04257696
# Training
# [863] average loss per epoch: 0.02043503
# Validation
# Average Validation loss per epoch: 0.04051697
# Training
# [864] average loss per epoch: 0.01994973
# Validation
# Average Validation loss per epoch: 0.03844415
# Training
# [865] average loss per epoch: 0.02011550
# Validation
# Average Validation loss per epoch: 0.03627517
# Training
# [866] average loss per epoch: 0.01885649
# Validation
# Average Validation loss per epoch: 0.03948749
# Training
# [867] average loss per epoch: 0.01741946
# Validation
# Average Validation loss per epoch: 0.04740033
# Training
# [868] average loss per epoch: 0.01817833
# Validation
# Average Validation loss per epoch: 0.05113281
# Training
# [869] average loss per epoch: 0.02000949
# Validation
# Average Validation loss per epoch: 0.04719409
# Training
# [870] average loss per epoch: 0.02006568
# Validation
# Average Validation loss per epoch: 0.04210505
# Training
# [871] average loss per epoch: 0.01883075
# Validation
# Average Validation loss per epoch: 0.03986792
# Training
# [872] average loss per epoch: 0.01844598
# Validation
# Average Validation loss per epoch: 0.03821430
# Training
# [873] average loss per epoch: 0.01850458
# Validation
# Average Validation loss per epoch: 0.03671980
# Training
# [874] average loss per epoch: 0.01772448
# Validation
# Average Validation loss per epoch: 0.03839837
# Training
# [875] average loss per epoch: 0.01667707
# Validation
# Average Validation loss per epoch: 0.04377620
# Training
# [876] average loss per epoch: 0.01684932
# Validation
# Average Validation loss per epoch: 0.04823204
# Training
# [877] average loss per epoch: 0.01806322
# Validation
# Average Validation loss per epoch: 0.04756809
# Training
# [878] average loss per epoch: 0.01866707
# Validation
# Average Validation loss per epoch: 0.04346945
# Training
# [879] average loss per epoch: 0.01815213
# Validation
# Average Validation loss per epoch: 0.04003450
# Training
# [880] average loss per epoch: 0.01761679
# Validation
# Average Validation loss per epoch: 0.03825304
# Training
# [881] average loss per epoch: 0.01769880
# Validation
# Average Validation loss per epoch: 0.03692930
# Training
# [882] average loss per epoch: 0.01770709
# Validation
# Average Validation loss per epoch: 0.03633941
# Training
# [883] average loss per epoch: 0.01702894
# Validation
# Average Validation loss per epoch: 0.03830767
# Training
# [884] average loss per epoch: 0.01624113
# Validation
# Average Validation loss per epoch: 0.04322898
# Training
# [885] average loss per epoch: 0.01642383
# Validation
# Average Validation loss per epoch: 0.04808232
# Training
# [886] average loss per epoch: 0.01753726
# Validation
# Average Validation loss per epoch: 0.04897991
# Training
# [887] average loss per epoch: 0.01842193
# Validation
# Average Validation loss per epoch: 0.04550133
# Training
# [888] average loss per epoch: 0.01832097
# Validation
# Average Validation loss per epoch: 0.04096971
# Training
# [889] average loss per epoch: 0.01772533
# Validation
# Average Validation loss per epoch: 0.03817975
# Training
# [890] average loss per epoch: 0.01759303
# Validation
# Average Validation loss per epoch: 0.03689089
# Training
# [891] average loss per epoch: 0.01794833
# Validation
# Average Validation loss per epoch: 0.03594331
# Training
# [892] average loss per epoch: 0.01792556
# Validation
# Average Validation loss per epoch: 0.03577821
# Training
# [893] average loss per epoch: 0.01707834
# Validation
# Average Validation loss per epoch: 0.03835040
# Training
# [894] average loss per epoch: 0.01625154
# Validation
# Average Validation loss per epoch: 0.04427765
# Training
# [895] average loss per epoch: 0.01665635
# Validation
# Average Validation loss per epoch: 0.05040982
# Training
# [896] average loss per epoch: 0.01816628
# Validation
# Average Validation loss per epoch: 0.05195693
# Training
# [897] average loss per epoch: 0.01944069
# Validation
# Average Validation loss per epoch: 0.04769894
# Training
# [898] average loss per epoch: 0.01947190
# Validation
# Average Validation loss per epoch: 0.04163830
# Training
# [899] average loss per epoch: 0.01864345
# Validation
# Average Validation loss per epoch: 0.03803602
# Training
# [900] average loss per epoch: 0.01831464
# Validation
# Average Validation loss per epoch: 0.03686816
# Training
# [901] average loss per epoch: 0.01888174
# Validation
# Average Validation loss per epoch: 0.03594463
# Training
# [902] average loss per epoch: 0.01918585
# Validation
# Average Validation loss per epoch: 0.03506345
# Training
# [903] average loss per epoch: 0.01818974
# Validation
# Average Validation loss per epoch: 0.03722411
# Training
# [904] average loss per epoch: 0.01682403
# Validation
# Average Validation loss per epoch: 0.04462961
# Training
# [905] average loss per epoch: 0.01717314
# Validation
# Average Validation loss per epoch: 0.05318195
# Training
# [906] average loss per epoch: 0.01936408
# Validation
# Average Validation loss per epoch: 0.05509698
# Training
# [907] average loss per epoch: 0.02120196
# Validation
# Average Validation loss per epoch: 0.04869662
# Training
# [908] average loss per epoch: 0.02097738
# Validation
# Average Validation loss per epoch: 0.04114101
# Training
# [909] average loss per epoch: 0.01957089
# Validation
# Average Validation loss per epoch: 0.03813673
# Training
# [910] average loss per epoch: 0.01932807
# Validation
# Average Validation loss per epoch: 0.03731832
# Training
# [911] average loss per epoch: 0.02020040
# Validation
# Average Validation loss per epoch: 0.03544231
# Training
# [912] average loss per epoch: 0.01997806
# Validation
# Average Validation loss per epoch: 0.03507144
# Training
# [913] average loss per epoch: 0.01805470
# Validation
# Average Validation loss per epoch: 0.04159162
# Training
# [914] average loss per epoch: 0.01724582
# Validation
# Average Validation loss per epoch: 0.05227484
# Training
# [915] average loss per epoch: 0.01956214
# Validation
# Average Validation loss per epoch: 0.05565629
# Training
# [916] average loss per epoch: 0.02209518
# Validation
# Average Validation loss per epoch: 0.04855811
# Training
# [917] average loss per epoch: 0.02162014
# Validation
# Average Validation loss per epoch: 0.04106119
# Training
# [918] average loss per epoch: 0.01967456
# Validation
# Average Validation loss per epoch: 0.03889440
# Training
# [919] average loss per epoch: 0.01953888
# Validation
# Average Validation loss per epoch: 0.03726603
# Training
# [920] average loss per epoch: 0.02012098
# Validation
# Average Validation loss per epoch: 0.03489932
# Training
# [921] average loss per epoch: 0.01895761
# Validation
# Average Validation loss per epoch: 0.03758898
# Training
# [922] average loss per epoch: 0.01717493
# Validation
# Average Validation loss per epoch: 0.04682978
# Training
# [923] average loss per epoch: 0.01801521
# Validation
# Average Validation loss per epoch: 0.05282620
# Training
# [924] average loss per epoch: 0.02052713
# Validation
# Average Validation loss per epoch: 0.04879048
# Training
# [925] average loss per epoch: 0.02082144
# Validation
# Average Validation loss per epoch: 0.04196366
# Training
# [926] average loss per epoch: 0.01908348
# Validation
# Average Validation loss per epoch: 0.03916177
# Training
# [927] average loss per epoch: 0.01848722
# Validation
# Average Validation loss per epoch: 0.03753476
# Training
# [928] average loss per epoch: 0.01883034
# Validation
# Average Validation loss per epoch: 0.03546993
# Training
# [929] average loss per epoch: 0.01800962
# Validation
# Average Validation loss per epoch: 0.03718878
# Training
# [930] average loss per epoch: 0.01661907
# Validation
# Average Validation loss per epoch: 0.04414123
# Training
# [931] average loss per epoch: 0.01699895
# Validation
# Average Validation loss per epoch: 0.04968927
# Training
# [932] average loss per epoch: 0.01876453
# Validation
# Average Validation loss per epoch: 0.04784923
# Training
# [933] average loss per epoch: 0.01924090
# Validation
# Average Validation loss per epoch: 0.04228511
# Training
# [934] average loss per epoch: 0.01814337
# Validation
# Average Validation loss per epoch: 0.03888411
# Training
# [935] average loss per epoch: 0.01752005
# Validation
# Average Validation loss per epoch: 0.03736135
# Training
# [936] average loss per epoch: 0.01778335
# Validation
# Average Validation loss per epoch: 0.03578100
# Training
# [937] average loss per epoch: 0.01748156
# Validation
# Average Validation loss per epoch: 0.03599001
# Training
# [938] average loss per epoch: 0.01637960
# Validation
# Average Validation loss per epoch: 0.04049310
# Training
# [939] average loss per epoch: 0.01606322
# Validation
# Average Validation loss per epoch: 0.04690894
# Training
# [940] average loss per epoch: 0.01726650
# Validation
# Average Validation loss per epoch: 0.04918467
# Training
# [941] average loss per epoch: 0.01843327
# Validation
# Average Validation loss per epoch: 0.04554464
# Training
# [942] average loss per epoch: 0.01824539
# Validation
# Average Validation loss per epoch: 0.04043947
# Training
# [943] average loss per epoch: 0.01738078
# Validation
# Average Validation loss per epoch: 0.03768862
# Training
# [944] average loss per epoch: 0.01719887
# Validation
# Average Validation loss per epoch: 0.03641910
# Training
# [945] average loss per epoch: 0.01750631
# Validation
# Average Validation loss per epoch: 0.03527063
# Training
# [946] average loss per epoch: 0.01715870
# Validation
# Average Validation loss per epoch: 0.03578849
# Training
# [947] average loss per epoch: 0.01614535
# Validation
# Average Validation loss per epoch: 0.04024785
# Training
# [948] average loss per epoch: 0.01591295
# Validation
# Average Validation loss per epoch: 0.04699903
# Training
# [949] average loss per epoch: 0.01712436
# Validation
# Average Validation loss per epoch: 0.05048288
# Training
# [950] average loss per epoch: 0.01850476
# Validation
# Average Validation loss per epoch: 0.04758081
# Training
# [951] average loss per epoch: 0.01870105
# Validation
# Average Validation loss per epoch: 0.04164780
# Training
# [952] average loss per epoch: 0.01787878
# Validation
# Average Validation loss per epoch: 0.03778382
# Training
# [953] average loss per epoch: 0.01740822
# Validation
# Average Validation loss per epoch: 0.03644135
# Training
# [954] average loss per epoch: 0.01777017
# Validation
# Average Validation loss per epoch: 0.03538541
# Training
# [955] average loss per epoch: 0.01787580
# Validation
# Average Validation loss per epoch: 0.03470286
# Training
# [956] average loss per epoch: 0.01692185
# Validation
# Average Validation loss per epoch: 0.03737194
# Training
# [957] average loss per epoch: 0.01601114
# Validation
# Average Validation loss per epoch: 0.04457747
# Training
# [958] average loss per epoch: 0.01676485
# Validation
# Average Validation loss per epoch: 0.05153914
# Training
# [959] average loss per epoch: 0.01865160
# Validation
# Average Validation loss per epoch: 0.05174674
# Training
# [960] average loss per epoch: 0.01975513
# Validation
# Average Validation loss per epoch: 0.04533976
# Training
# [961] average loss per epoch: 0.01919816
# Validation
# Average Validation loss per epoch: 0.03915494
# Training
# [962] average loss per epoch: 0.01815055
# Validation
# Average Validation loss per epoch: 0.03694991
# Training
# [963] average loss per epoch: 0.01821045
# Validation
# Average Validation loss per epoch: 0.03609538
# Training
# [964] average loss per epoch: 0.01878558
# Validation
# Average Validation loss per epoch: 0.03456160
# Training
# [965] average loss per epoch: 0.01817048
# Validation
# Average Validation loss per epoch: 0.03527203
# Training
# [966] average loss per epoch: 0.01663239
# Validation
# Average Validation loss per epoch: 0.04213292
# Training
# [967] average loss per epoch: 0.01668537
# Validation
# Average Validation loss per epoch: 0.05153373
# Training
# [968] average loss per epoch: 0.01891267
# Validation
# Average Validation loss per epoch: 0.05395527
# Training
# [969] average loss per epoch: 0.02068589
# Validation
# Average Validation loss per epoch: 0.04715871
# Training
# [970] average loss per epoch: 0.02014893
# Validation
# Average Validation loss per epoch: 0.03976047
# Training
# [971] average loss per epoch: 0.01864654
# Validation
# Average Validation loss per epoch: 0.03745554
# Training
# [972] average loss per epoch: 0.01863704
# Validation
# Average Validation loss per epoch: 0.03645547
# Training
# [973] average loss per epoch: 0.01931956
# Validation
# Average Validation loss per epoch: 0.03435377
# Training
# [974] average loss per epoch: 0.01843022
# Validation
# Average Validation loss per epoch: 0.03572753
# Training
# [975] average loss per epoch: 0.01664648
# Validation
# Average Validation loss per epoch: 0.04436807
# Training
# [976] average loss per epoch: 0.01721842
# Validation
# Average Validation loss per epoch: 0.05299107
# Training
# [977] average loss per epoch: 0.01989151
# Validation
# Average Validation loss per epoch: 0.05147256
# Training
# [978] average loss per epoch: 0.02088171
# Validation
# Average Validation loss per epoch: 0.04320353
# Training
# [979] average loss per epoch: 0.01928654
# Validation
# Average Validation loss per epoch: 0.03840544
# Training
# [980] average loss per epoch: 0.01819246
# Validation
# Average Validation loss per epoch: 0.03727306
# Training
# [981] average loss per epoch: 0.01880997
# Validation
# Average Validation loss per epoch: 0.03516891
# Training
# [982] average loss per epoch: 0.01863413
# Validation
# Average Validation loss per epoch: 0.03464998
# Training
# [983] average loss per epoch: 0.01689790
# Validation
# Average Validation loss per epoch: 0.04084768
# Training
# [984] average loss per epoch: 0.01646883
# Validation
# Average Validation loss per epoch: 0.04977648
# Training
# [985] average loss per epoch: 0.01863666
# Validation
# Average Validation loss per epoch: 0.05091147
# Training
# [986] average loss per epoch: 0.02007063
# Validation
# Average Validation loss per epoch: 0.04419889
# Training
# [987] average loss per epoch: 0.01893173
# Validation
# Average Validation loss per epoch: 0.03884029
# Training
# [988] average loss per epoch: 0.01762112
# Validation
# Average Validation loss per epoch: 0.03725355
# Training
# [989] average loss per epoch: 0.01793505
# Validation
# Average Validation loss per epoch: 0.03550521
# Training
# [990] average loss per epoch: 0.01798867
# Validation
# Average Validation loss per epoch: 0.03461093
# Training
# [991] average loss per epoch: 0.01663914
# Validation
# Average Validation loss per epoch: 0.03906203
# Training
# [992] average loss per epoch: 0.01595401
# Validation
# Average Validation loss per epoch: 0.04713986
# Training
# [993] average loss per epoch: 0.01751609
# Validation
# Average Validation loss per epoch: 0.05010241
# Training
# [994] average loss per epoch: 0.01902909
# Validation
# Average Validation loss per epoch: 0.04524044
# Training
# [995] average loss per epoch: 0.01848902
# Validation
# Average Validation loss per epoch: 0.03941075
# Training
# [996] average loss per epoch: 0.01723177
# Validation
# Average Validation loss per epoch: 0.03709831
# Training
# [997] average loss per epoch: 0.01720410
# Validation
# Average Validation loss per epoch: 0.03580852
# Training
# [998] average loss per epoch: 0.01751035
# Validation
# Average Validation loss per epoch: 0.03451404
# Training
# [999] average loss per epoch: 0.01666368
# Validation
# Average Validation loss per epoch: 0.03665002
# Training
# [1000] average loss per epoch: 0.01563534
# Validation
# Average Validation loss per epoch: 0.04360266
# Finished Training

# %%
model.load_state_dict(torch.load(TRAIN_PATH))
model.to(device)
# Out:
# AutoEncoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=1000, out_features=512, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=256, out_features=64, bias=True)
#     (5): Tanh()
#     (6): Linear(in_features=64, out_features=32, bias=True)
#     (7): Tanh()
#   )
#   (decoder): myLayer(
#     (fc1): Linear(in_features=32, out_features=16, bias=True)
#     (fc2): Linear(in_features=16, out_features=1, bias=True)
#     (activation_fn): Tanh()
#   )
# )

# %%
def test(model):
    predictions = []
    model.eval()
    with torch.no_grad():
        for i, data in tqdm(enumerate(test_loader)):
            feature = data.to(device)
            predict = model(feature)
            predict = predict.cpu().numpy()
            predictions.append(predict)
    return predictions

# %%
predictions = test(model)
output = []
for i in range(len(predictions)):
    for j in range(len(predictions[i])):
        output.append(predictions[i][j])


output = np.hstack((test_id, output))
df_output = pd.DataFrame(output)
df_output.columns = ['Id', 'y']
df_output.to_csv(SAVE_PATH, index=False)
# Out:
# 40it [00:00, 444.49it/s]
